# %%
import pandas as pd

# %%
emp={'id':[101,102,103,104,105],
'Nmae':['deepak','shyam','arun','manu','rohan'],
'Age':[25,22,24,20,27],
'Salary':[25000,30000,150000,100000,300000]}
df=pd.DataFrame(emp)

# %%
df
# Out:
#     id    Nmae  Age  Salary
# 0  101  deepak   25   25000
# 1  102   shyam   22   30000
# 2  103    arun   24  150000
# 3  104    manu   20  100000
# 4  105   rohan   27  300000

# %%
emp_data=[(101,'deepak',25,25000),
(102,'shyam',22,300000),(103,'arun',24,150000),
(104,'manu',20,10000),(105,'jenna',27,300000)]
df=pd.DataFrame(emp_data,columns=['id','name','age','salary'])

# %%
df
# Out:
#     id    name  age  salary
# 0  101  deepak   25   25000
# 1  102   shyam   22  300000
# 2  103    arun   24  150000
# 3  104    manu   20   10000
# 4  105   jenna   27  300000

# %%
a=[1,2,7]
myvar=pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    2
# 2    7
# dtype: int64

# %%
a=[1,2,7]
myvar=pd.Series(a)
print(myvar[0])
# Out:
# 1

# %%
a=[1,2,7]
myvar=pd.Series(a,index=["x","y","z"])
print(myvar)
# Out:
# x    1
# y    2
# z    7
# dtype: int64

# %%
calories={"day1":420,"day2":380,"day3":390}
myvar=pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
calories={"day1":420,"day2":380,"day3":390}
myvar=pd.Series(calories,index=["day1","day2"])
print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
df=pd.read_excel(r'C:\study materials\data science\pandas\employee.xlsx',)

# %%
df
# Out:
#       Unnamed: 0  gender  dob  occupation  work_exp  salary  own_house  \
# 0     1981-01-01     NaN  NaN         NaN       NaN     NaN        NaN
# 1     1981-01-02     NaN  NaN         NaN       NaN     NaN        NaN
# 2     1981-01-03     NaN  NaN         NaN       NaN     NaN        NaN
# 3     1981-01-04     NaN  NaN         NaN       NaN     NaN        NaN
# 4     1981-01-05     NaN  NaN         NaN       NaN     NaN        NaN
# ...          ...     ...  ...         ...       ...     ...        ...
# 5120  1995-01-08     NaN  NaN         NaN       NaN     NaN        NaN
# 5121  1995-01-09     NaN  NaN         NaN       NaN     NaN        NaN
# 5122  1995-01-10     NaN  NaN         NaN       NaN     NaN        NaN
# 5123  1995-01-11     NaN  NaN         NaN       NaN     NaN        NaN
# 5124  1995-01-12     NaN  NaN         NaN       NaN     NaN        NaN
#
#       children
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# ...

# %%
df=pd.read_csv(r'C:\study materials\data science\pandas\stock_data.csv',)

# %%
df
# Out:
#             Date   Open   High    Low  Close    Volume   Name
# 0       1/3/2006  39.69  41.22  38.79  40.91  24232729   AABA
# 1       1/4/2006  41.22  41.90  40.77  40.97  20553479   AABA
# 2       1/5/2006  40.93  41.73  40.85  41.53  12829610   AABA
# 3       1/6/2006  42.88  43.57  42.80  43.21  29422828   alex
# 4       1/9/2006  43.10  43.66  42.82  43.42  16268338  queen
# ...          ...    ...    ...    ...    ...       ...    ...
# 3014  12/22/2017  71.42  71.87  71.22  71.58  10979165   AABA
# 3015  12/26/2017  70.94  71.39  69.63  69.86   8542802   AABA
# 3016  12/27/2017  69.77  70.49  69.69  70.06   6345124   AABA
# 3017  12/28/2017  70.12  70.32  69.51  69.82   7556877   AABA
# 3018  12/29/2017  69.79  70.13  69.43  69.85   6613070   AABA
#
# [3019 rows x 7 columns]

# %%
df=pd.read_csv(r'C:\study materials\data science\pandas\stock_data.csv',nrows=3)

# %%
df
# Out:
#        Date   Open   High    Low  Close    Volume  Name
# 0  1/3/2006  39.69  41.22  38.79  40.91  24232729  AABA
# 1  1/4/2006  41.22  41.90  40.77  40.97  20553479  AABA
# 2  1/5/2006  40.93  41.73  40.85  41.53  12829610  AABA

# %%
df=pd.read_csv(r'C:\study materials\data science\pandas\stock_data.csv',na_values=['n.a','not available'])

# %%
df
# Out:
#             Date   Open   High    Low  Close    Volume   Name
# 0       1/3/2006  39.69  41.22  38.79  40.91  24232729   AABA
# 1       1/4/2006  41.22  41.90  40.77  40.97  20553479   AABA
# 2       1/5/2006  40.93  41.73  40.85  41.53  12829610   AABA
# 3       1/6/2006  42.88  43.57  42.80  43.21  29422828   alex
# 4       1/9/2006  43.10  43.66  42.82  43.42  16268338  queen
# ...          ...    ...    ...    ...    ...       ...    ...
# 3014  12/22/2017  71.42  71.87  71.22  71.58  10979165   AABA
# 3015  12/26/2017  70.94  71.39  69.63  69.86   8542802   AABA
# 3016  12/27/2017  69.77  70.49  69.69  70.06   6345124   AABA
# 3017  12/28/2017  70.12  70.32  69.51  69.82   7556877   AABA
# 3018  12/29/2017  69.79  70.13  69.43  69.85   6613070   AABA
#
# [3019 rows x 7 columns]

# %%
df.to_csv(r'C:\study materials\data science\pandas\xyz_data.csv',index=False,columns=['Open','Close'])

# %%
df
# Out:
#   gender        dob  occupation  work_exp    salary  own_house  children
# 0      M 1989-07-31       nurse       2.2  223700.0       True         1
# 1    NaN 1992-10-30     dentist       6.7  121100.0       True         1
# 2      F        NaT  accountant       9.0       NaN      False         2
# 3      F 1987-09-17    engineer       1.7   79900.0      False         0
# 4      M 1993-01-24     teacher       3.6   32800.0      False         2
# 5      F        NaT   developer       1.8       NaN       True         1
# 6      F 1994-09-26       nurse       5.6  272500.0      False         1
# 7      M 1991-05-07      lawyer       4.1   41600.0      False         0
# 8      M 1994-12-04     teacher       3.3  141300.0       True         0
# 9      M 1987-07-10      police       6.5   68000.0       True         1

# %%
def convert_occupation(co):
    if co=='nurse':
        return'doctor'
    else:
        return co

# %%
data=pd.read_excel(r'C:\study materials\data science\pandas\employee.xlsx',
converters={'occupation':convert_occupation})

# %%
data
# Out:
#   gender        dob  occupation  work_exp    salary  own_house  children
# 0      M 1989-07-31      doctor       2.2  223700.0       True         1
# 1    NaN 1992-10-30     dentist       6.7  121100.0       True         1
# 2      F        NaT  accountant       9.0       NaN      False         2
# 3      F 1987-09-17    engineer       1.7   79900.0      False         0
# 4      M 1993-01-24     teacher       3.6   32800.0      False         2
# 5      F        NaT   developer       1.8       NaN       True         1
# 6      F 1994-09-26      doctor       5.6  272500.0      False         1
# 7      M 1991-05-07      lawyer       4.1   41600.0      False         0
# 8      M 1994-12-04     teacher       3.3  141300.0       True         0
# 9      M 1987-07-10      police       6.5   68000.0       True         1

# %%
with pd.ExcelWriter(r'C:\study materials\data science\pandas\new.xlsx') as wr:
    df.to_excel(wr,sheet_name="employee")
    data.to_excel(wr,sheet_name='new')

# %%
df=pd.read_excel(r'C:\study materials\data science\pandas\employee.xlsx')

# %%
df
# Out:
#   gender        dob  occupation  work_exp    salary  own_house  children
# 0      M 1989-07-31       nurse       2.2  223700.0       True         1
# 1    NaN 1992-10-30     dentist       6.7  121100.0       True         1
# 2      F        NaT  accountant       9.0       NaN      False         2
# 3      F 1987-09-17    engineer       1.7   79900.0      False         0
# 4      M 1993-01-24     teacher       3.6   32800.0      False         2
# 5      F        NaT   developer       1.8       NaN       True         1
# 6      F 1994-09-26       nurse       5.6  272500.0      False         1
# 7      M 1991-05-07      lawyer       4.1   41600.0      False         0
# 8      M 1994-12-04     teacher       3.3  141300.0       True         0
# 9      M 1987-07-10      police       6.5   68000.0       True         1

# %%
df.set_index('dob')
# Out:
#            gender  occupation  work_exp    salary  own_house  children
# dob
# 1989-07-31      M       nurse       2.2  223700.0       True         1
# 1992-10-30    NaN     dentist       6.7  121100.0       True         1
# NaT             F  accountant       9.0       NaN      False         2
# 1987-09-17      F    engineer       1.7   79900.0      False         0
# 1993-01-24      M     teacher       3.6   32800.0      False         2
# NaT             F   developer       1.8       NaN       True         1
# 1994-09-26      F       nurse       5.6  272500.0      False         1
# 1991-05-07      M      lawyer       4.1   41600.0      False         0
# 1994-12-04      M     teacher       3.3  141300.0       True         0
# 1987-07-10      M      police       6.5   68000.0       True         1

# %%
type(df['dob'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df=pd.read_excel(r'C:\study materials\data science\pandas\employee.xlsx',parse_dates=['dob'])

# %%
df
# Out:
#   gender        dob  occupation  work_exp    salary  own_house  children
# 0      M 1989-07-31       nurse       2.2  223700.0       True         1
# 1    NaN 1992-10-30     dentist       6.7  121100.0       True         1
# 2      F        NaT  accountant       9.0       NaN      False         2
# 3      F 1987-09-17    engineer       1.7   79900.0      False         0
# 4      M 1993-01-24     teacher       3.6   32800.0      False         2
# 5      F        NaT   developer       1.8       NaN       True         1
# 6      F 1994-09-26       nurse       5.6  272500.0      False         1
# 7      M 1991-05-07      lawyer       4.1   41600.0      False         0
# 8      M 1994-12-04     teacher       3.3  141300.0       True         0
# 9      M 1987-07-10      police       6.5   68000.0       True         1

# %%
ind=pd.date_range('1981-01-01','1995-01-12')

# %%
index=pd.DatetimeIndex(ind)

# %%
data = data.reindex(index)

# %%
data
# Out:
#            gender dob occupation  work_exp  salary own_house  children
# 1981-01-01    NaN NaT        NaN       NaN     NaN       NaN       NaN
# 1981-01-02    NaN NaT        NaN       NaN     NaN       NaN       NaN
# 1981-01-03    NaN NaT        NaN       NaN     NaN       NaN       NaN
# 1981-01-04    NaN NaT        NaN       NaN     NaN       NaN       NaN
# 1981-01-05    NaN NaT        NaN       NaN     NaN       NaN       NaN
# ...           ...  ..        ...       ...     ...       ...       ...
# 1995-01-08    NaN NaT        NaN       NaN     NaN       NaN       NaN
# 1995-01-09    NaN NaT        NaN       NaN     NaN       NaN       NaN
# 1995-01-10    NaN NaT        NaN       NaN     NaN       NaN       NaN
# 1995-01-11    NaN NaT        NaN       NaN     NaN       NaN       NaN
# 1995-01-12    NaN NaT        NaN       NaN     NaN       NaN       NaN
#
# [5125 rows x 7 columns]

# %%
data.to_csv(r'C:\study materials\data science\pandas\abc_data.csv')

# %%
df=pd.read_csv(r'C:\study materials\data science\pandas\abc_data.csv',)

# %%
df
# Out:
#       Unnamed: 0  gender  dob  occupation  work_exp  salary  own_house  \
# 0     1981-01-01     NaN  NaN         NaN       NaN     NaN        NaN
# 1     1981-01-02     NaN  NaN         NaN       NaN     NaN        NaN
# 2     1981-01-03     NaN  NaN         NaN       NaN     NaN        NaN
# 3     1981-01-04     NaN  NaN         NaN       NaN     NaN        NaN
# 4     1981-01-05     NaN  NaN         NaN       NaN     NaN        NaN
# ...          ...     ...  ...         ...       ...     ...        ...
# 5120  1995-01-08     NaN  NaN         NaN       NaN     NaN        NaN
# 5121  1995-01-09     NaN  NaN         NaN       NaN     NaN        NaN
# 5122  1995-01-10     NaN  NaN         NaN       NaN     NaN        NaN
# 5123  1995-01-11     NaN  NaN         NaN       NaN     NaN        NaN
# 5124  1995-01-12     NaN  NaN         NaN       NaN     NaN        NaN
#
#       children
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# ...

# %%
#fillna()
new_df=df.fillna(5)
#new_df=data.fillna

# %%
new_df
# Out:
#       Unnamed: 0  gender  dob  occupation  work_exp  salary  own_house  \
# 0     1981-01-01     5.0  5.0         5.0       5.0     5.0        5.0
# 1     1981-01-02     5.0  5.0         5.0       5.0     5.0        5.0
# 2     1981-01-03     5.0  5.0         5.0       5.0     5.0        5.0
# 3     1981-01-04     5.0  5.0         5.0       5.0     5.0        5.0
# 4     1981-01-05     5.0  5.0         5.0       5.0     5.0        5.0
# ...          ...     ...  ...         ...       ...     ...        ...
# 5120  1995-01-08     5.0  5.0         5.0       5.0     5.0        5.0
# 5121  1995-01-09     5.0  5.0         5.0       5.0     5.0        5.0
# 5122  1995-01-10     5.0  5.0         5.0       5.0     5.0        5.0
# 5123  1995-01-11     5.0  5.0         5.0       5.0     5.0        5.0
# 5124  1995-01-12     5.0  5.0         5.0       5.0     5.0        5.0
#
#       children
# 0          5.0
# 1          5.0
# 2          5.0
# 3          5.0
# 4          5.0
# ...        ...
# ...

# %%
new_df=data.interpolte()
new_df=data.interpolate(method='time')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10396\3860023898.py in ?()
# ----> 1 new_df=data.interpolte()
#       2 new_df=data.interpolate(method='time')
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'interpolte'

# %%
print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5120    False
# 5121    False
# 5122    False
# 5123    False
# 5124    False
# Length: 5125, dtype: bool

# %%
df=pd.read_excel(r'C:\study materials\data science\pandas\new.xlsx','Sheet1')

# %%
df
# Out:
#       a a.1 a.2 a.3 a.4
# 0     a   a   a   a   a
# 1     f   1   1   b   h
# 2     r   1   1   b   g
# 3    yh   1   1   b   g
# 4     j   1   1   c   g
# 5     f   2   2   c   h
# 6     d   2   2   c   h
# 7   fdh   2   2   c   h
# 8     e   2   2   c   h
# 9     a   a   a   a   a
# 10    a   a   a   a   a
# 11    f   1   1   b   h
# 12    r   1   1   b   g
# 13   yh   1   1   b   g
# 14    j   1   1   c   g
# 15    f   2   2   c   h
# 16    d   2   2   c   h
# 17  fdh   2   2   c   h
# 18    e   2   2   c   h

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# dtype: bool

# %%
df=pd.read_csv(r'C:\study materials\data science\pandas\weather.csv')

# %%
df
# Out:
#        Data.Precipitation Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  1/3/2016           1             3       2016
# 1                    0.00  1/3/2016           1             3       2016
# 2                    0.16  1/3/2016           1             3       2016
# 3                    0.00  1/3/2016           1             3       2016
# 4                    0.01  1/3/2016           1             3       2016
# ...                   ...       ...         ...           ...        ...
# 16738                0.08  1/1/2017           1             1       2017
# 16739                0.00  1/1/2017           1             1       2017
# 16740                0.00  1/1/2017           1             1       2017
# 16741                0.06  1/1/2017           1             1       2017
# 16742                0.10  1/1/2017           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
(df.groupby('Station.State'))

# %%
grp_result

# %%
df=pd.read_csv(r'C:\study materials\data science\pandas\weather2.csv')

# %%
df
# Out:
#           Day      City  Temperature  WindSpeed   event
# 0    1/1/2017  new work           30          6    rain
# 1    1/2/2017  new work           36          7   sunny
# 2    1/3/2017  new work           28         12    snow
# 3   1/4/20017  new work           33          7   sunny
# 4    1/1/2017    mumbai           90          5   sunny
# 5    1/2/2017    mumbai           85         12     fog
# 6    1/3/2017    mumbai           87         15     fog
# 7    1/4/2017    mumbai           92          5    rain
# 8    1/1/2017    paries           45         20   sunny
# 9    1/2/2017    paries           50         13  cloudy
# 10   1/3/2017    paries           54          8  cloudy
# 11   1/4/2017    paries           42         10  cloudy

# %%
cf=df.groupby('City')

# %%
cf

# %%
cf.get_group('new work')
# Out:
#          Day      City  Temperature  WindSpeed  event
# 0   1/1/2017  new work           30          6   rain
# 1   1/2/2017  new work           36          7  sunny
# 2   1/3/2017  new work           28         12   snow
# 3  1/4/20017  new work           33          7  sunny

# %%
for city,city_df in cf:
    print(city)
    print(city_df)
# Out:
# mumbai
#         Day    City  Temperature  WindSpeed  event
# 4  1/1/2017  mumbai           90          5  sunny
# 5  1/2/2017  mumbai           85         12    fog
# 6  1/3/2017  mumbai           87         15    fog
# 7  1/4/2017  mumbai           92          5   rain
# new work
#          Day      City  Temperature  WindSpeed  event
# 0   1/1/2017  new work           30          6   rain
# 1   1/2/2017  new work           36          7  sunny
# 2   1/3/2017  new work           28         12   snow
# 3  1/4/20017  new work           33          7  sunny
# paries
#          Day    City  Temperature  WindSpeed   event
# 8   1/1/2017  paries           45         20   sunny
# 9   1/2/2017  paries           50         13  cloudy
# 10  1/3/2017  paries           54          8  cloudy
# 11  1/4/2017  paries           42         10  cloudy

# %%
tcs={'id':[101,102,103,104],'name':['mithun','dipin','jose','rahul'],
'age':[24,25,26,27]}

# %%
wipro={'id':[101,102,103,104],'name':['dev','jay','bijoy','bicky'],
'age':[24,24,27,26]}

# %%
tcs_emp=pd.DataFrame(tcs)
wipro_emp=pd.DataFrame(wipro)

# %%
pd.concat([tcs_emp,wipro_emp])
# Out:
#     id    name  age
# 0  101  mithun   24
# 1  102   dipin   25
# 2  103    jose   26
# 3  104   rahul   27
# 0  101     dev   24
# 1  102     jay   24
# 2  103   bijoy   27
# 3  104   bicky   26

# %%
tcs={'id':[101,102,103,104],
'name':['mithun','dipin','jose','rahul'],'age':[25,26,27,29]}

# %%
wipro={'id':[101,102,103,105],'name':['dev','jay','bijoy','bicky'],
'salary':[25000,34000,37000,20000]}

# %%
tcs_emp=pd.DataFrame(tcs)
wipro_emp=pd.DataFrame(wipro)
pd.merge(tcs_emp,wipro_emp,on='id')
# Out:
#     id  name_x  age name_y  salary
# 0  101  mithun   25    dev   25000
# 1  102   dipin   26    jay   34000
# 2  103    jose   27  bijoy   37000

# %%
pd.merge(tcs_emp,wipro_emp,on='id',suffixes=['_left','_right'])
# Out:
#     id name_left  age name_right  salary
# 0  101    mithun   25        dev   25000
# 1  102     dipin   26        jay   34000
# 2  103      jose   27      bijoy   37000

# %%
pd.merge(tcs_emp,wipro_emp,on='id',how='outer')
# Out:
#     id  name_x   age name_y   salary
# 0  101  mithun  25.0    dev  25000.0
# 1  102   dipin  26.0    jay  34000.0
# 2  103    jose  27.0  bijoy  37000.0
# 3  104   rahul  29.0    NaN      NaN
# 4  105     NaN   NaN  bicky  20000.0

# %%
pd.merge(tcs_emp,wipro_emp,on='id',how='outer',indicator=True)
# Out:
#     id  name_x   age name_y   salary      _merge
# 0  101  mithun  25.0    dev  25000.0        both
# 1  102   dipin  26.0    jay  34000.0        both
# 2  103    jose  27.0  bijoy  37000.0        both
# 3  104   rahul  29.0    NaN      NaN   left_only
# 4  105     NaN   NaN  bicky  20000.0  right_only

# %%
pd.merge(tcs_emp,wipro_emp,on='id',how='left')
# Out:
#     id  name_x  age name_y   salary
# 0  101  mithun   25    dev  25000.0
# 1  102   dipin   26    jay  34000.0
# 2  103    jose   27  bijoy  37000.0
# 3  104   rahul   29    NaN      NaN

# %%
pd.merge(tcs_emp,wipro_emp,on='id',how='right')
# Out:
#     id  name_x   age name_y  salary
# 0  101  mithun  25.0    dev   25000
# 1  102   dipin  26.0    jay   34000
# 2  103    jose  27.0  bijoy   37000
# 3  105     NaN   NaN  bicky   20000

# %%
datas=pd.read_csv(r'C:\study materials\data science\pandas\weather2.csv')

# %%
datas
# Out:
#           Day      City  Temperature  WindSpeed   event
# 0    1/1/2017  new work           30          6    rain
# 1    1/2/2017  new work           36          7   sunny
# 2    1/3/2017  new work           28         12    snow
# 3   1/4/20017  new work           33          7   sunny
# 4    1/1/2017    mumbai           90          5   sunny
# 5    1/2/2017    mumbai           85         12     fog
# 6    1/3/2017    mumbai           87         15     fog
# 7    1/4/2017    mumbai           92          5    rain
# 8    1/1/2017    paries           45         20   sunny
# 9    1/2/2017    paries           50         13  cloudy
# 10   1/3/2017    paries           54          8  cloudy
# 11   1/4/2017    paries           42         10  cloudy

# %%
datas.pivot(index='Day',columns='City')
# Out:
#           Temperature                 WindSpeed                  event  \
# City           mumbai new work paries    mumbai new work paries mumbai
# Day
# 1/1/2017         90.0     30.0   45.0       5.0      6.0   20.0  sunny
# 1/2/2017         85.0     36.0   50.0      12.0      7.0   13.0    fog
# 1/3/2017         87.0     28.0   54.0      15.0     12.0    8.0    fog
# 1/4/20017         NaN     33.0    NaN       NaN      7.0    NaN    NaN
# 1/4/2017         92.0      NaN   42.0       5.0      NaN   10.0   rain
#
#
# City      new work  paries
# Day
# 1/1/2017      rain   sunny
# 1/2/2017     sunny  cloudy
# 1/3/2017      snow  cloudy
# 1/4/20017    sunny     NaN
# 1/4/2017       NaN  cloudy

# %%
datas.pivot(index='Day',columns='City',values='Temperature')
# Out:
# City       mumbai  new work  paries
# Day
# 1/1/2017     90.0      30.0    45.0
# 1/2/2017     85.0      36.0    50.0
# 1/3/2017     87.0      28.0    54.0
# 1/4/20017     NaN      33.0     NaN
# 1/4/2017     92.0       NaN    42.0

# %%
datas=pd.read_csv(r'C:\study materials\data science\pandas\weather3.csv')

# %%
datas
# Out:
#           Day      City  Temperature  WindSpeed
# 0    1/1/2017  new work           30          6
# 1    1/2/2017  new work           36          7
# 2    1/3/2017  new work           28         12
# 3   1/4/20017  new work           33          7
# 4    1/1/2017    mumbai           90          5
# 5    1/2/2017    mumbai           85         12
# 6    1/3/2017    mumbai           87         15
# 7    1/4/2017    mumbai           92          5
# 8    1/1/2017    paries           45         20
# 9    1/2/2017    paries           50         13
# 10   1/3/2017    paries           54          8
# 11   1/4/2017    paries           42         10

# %%
datas.pivot_table(index='City',columns='Day')
# Out:
#          Temperature                                      WindSpeed           \
# Day         1/1/2017 1/2/2017 1/3/2017 1/4/20017 1/4/2017  1/1/2017 1/2/2017
# City
# mumbai          90.0     85.0     87.0       NaN     92.0       5.0     12.0
# new work        30.0     36.0     28.0      33.0      NaN       6.0      7.0
# paries          45.0     50.0     54.0       NaN     42.0      20.0     13.0
#
#
# Day      1/3/2017 1/4/20017 1/4/2017
# City
# mumbai       15.0       NaN      5.0
# new work     12.0       7.0      NaN
# paries        8.0       NaN     10.0

# %%
datas.pivot_table(index='City',columns='Day',aggfunc='sum')
# Out:
#          Temperature                                      WindSpeed           \
# Day         1/1/2017 1/2/2017 1/3/2017 1/4/20017 1/4/2017  1/1/2017 1/2/2017
# City
# mumbai          90.0     85.0     87.0       NaN     92.0       5.0     12.0
# new work        30.0     36.0     28.0      33.0      NaN       6.0      7.0
# paries          45.0     50.0     54.0       NaN     42.0      20.0     13.0
#
#
# Day      1/3/2017 1/4/20017 1/4/2017
# City
# mumbai       15.0       NaN      5.0
# new work     12.0       7.0      NaN
# paries        8.0       NaN     10.0

# %%
datas.pivot_table(index='City',columns='Day',aggfunc='sum',margins=True)
# Out:
#          Temperature                                           WindSpeed  \
# Day         1/1/2017 1/2/2017 1/3/2017 1/4/20017 1/4/2017  All  1/1/2017
# City
# mumbai          90.0     85.0     87.0       NaN     92.0  354       5.0
# new work        30.0     36.0     28.0      33.0      NaN  127       6.0
# paries          45.0     50.0     54.0       NaN     42.0  191      20.0
# All            165.0    171.0    169.0      33.0    134.0  672      31.0
#
#
# Day      1/2/2017 1/3/2017 1/4/20017 1/4/2017  All
# City
# mumbai       12.0     15.0       NaN      5.0   37
# new work      7.0     12.0       7.0      NaN   32
# paries       13.0      8.0       NaN     10.0   51
# All          32.0     35.0       7.0     15.0  120

# %%
datas=pd.read_csv(r'C:\study materials\data science\pandas\weather3.csv')

# %%
datas['Day']=pd.to_datetime(datas['Day'])

# %%
datas
# Out:
#           Day      City  Temperature  WindSpeed
# 0  2017-01-01  new work           30          6
# 1  2017-01-02  new work           36          7
# 2  2017-01-03  new work           28         12
# 3  2017-01-04  new work           33          7
# 4  2017-01-01    mumbai           90          5
# 5  2017-01-02    mumbai           85         12
# 6  2017-01-03    mumbai           87         15
# 7  2017-01-04    mumbai           92          5
# 8  2017-01-01    paries           45         20
# 9  2017-01-02    paries           50         13
# 10 2017-01-03    paries           54          8
# 11 2017-01-04    paries           42         10

# %%
datas.pivot_table(index=pd.Grouper(freq='M',key='Day'),columns='City')
# Out:
#            Temperature                 WindSpeed
# City            mumbai new work paries    mumbai new work paries
# Day
# 2017-01-31        88.5    31.75  47.75      9.25      8.0  12.75

# %%
datas.pivot_table(index=pd.Grouper(freq='M',key='Day'),columns='City',aggfunc='sum')
# Out:
#            Temperature                 WindSpeed
# City            mumbai new work paries    mumbai new work paries
# Day
# 2017-01-31         354      127    191        37       32     51

# %%
pd.melt(datas,id_vars=['Day'])
# Out:
#           Day     variable     value
# 0  2017-01-01         City  new work
# 1  2017-01-02         City  new work
# 2  2017-01-03         City  new work
# 3  2017-01-04         City  new work
# 4  2017-01-01         City    mumbai
# 5  2017-01-02         City    mumbai
# 6  2017-01-03         City    mumbai
# 7  2017-01-04         City    mumbai
# 8  2017-01-01         City    paries
# 9  2017-01-02         City    paries
# 10 2017-01-03         City    paries
# 11 2017-01-04         City    paries
# 12 2017-01-01  Temperature        30
# 13 2017-01-02  Temperature        36
# 14 2017-01-03  Temperature        28
# 15 2017-01-04  Temperature        33
# 16 2017-01-01  Temperature        90
# 17 2017-01-02  Temperature        85
# 18 2017-01-03  Temperature        87
# 19 2017-01-04  Temperature        92
# 20 2017-01-01  Temperature        45
# 21 2017-01-02  Temperature        50
# 22 2017-01-03  Temperature        54
# 23 2017-01-04  Temperature        42
# ...

# %%
pd.melt(datas,id_vars=['Day'],value_name='Tempreture',var_name='City')
# Out:
#           Day         City Tempreture
# 0  2017-01-01         City   new work
# 1  2017-01-02         City   new work
# 2  2017-01-03         City   new work
# 3  2017-01-04         City   new work
# 4  2017-01-01         City     mumbai
# 5  2017-01-02         City     mumbai
# 6  2017-01-03         City     mumbai
# 7  2017-01-04         City     mumbai
# 8  2017-01-01         City     paries
# 9  2017-01-02         City     paries
# 10 2017-01-03         City     paries
# 11 2017-01-04         City     paries
# 12 2017-01-01  Temperature         30
# 13 2017-01-02  Temperature         36
# 14 2017-01-03  Temperature         28
# 15 2017-01-04  Temperature         33
# 16 2017-01-01  Temperature         90
# 17 2017-01-02  Temperature         85
# 18 2017-01-03  Temperature         87
# 19 2017-01-04  Temperature         92
# 20 2017-01-01  Temperature         45
# 21 2017-01-02  Temperature         50
# 22 2017-01-03  Temperature         54
# 23 2017-01-04  Temperature         42
# ...

# %%
df=pd.read_csv(r'C:\study materials\data science\pandas\weather2.csv')

# %%
df.head(2)
# Out:
#         Day      City  Temperature  WindSpeed  event
# 0  1/1/2017  new work           30          6   rain
# 1  1/2/2017  new work           36          7  sunny

# %%
pd.crosstab(df.City,df.event)
# Out:
# event     cloudy  fog  rain  snow  sunny
# City
# mumbai         0    2     1     0      1
# new work       0    0     1     1      2
# paries         3    0     0     0      1

# %%
pd.crosstab(df.City,df.event,margins=True)
# Out:
# event     cloudy  fog  rain  snow  sunny  All
# City
# mumbai         0    2     1     0      1    4
# new work       0    0     1     1      2    4
# paries         3    0     0     0      1    4
# All            3    2     2     1      4   12

# %%
import numpy as np

# %%
pd.crosstab(df.City,df.event,values=df.Temperature,aggfunc=np.average)
# Out:
# event        cloudy   fog  rain  snow  sunny
# City
# mumbai          NaN  86.0  92.0   NaN   90.0
# new work        NaN   NaN  30.0  28.0   34.5
# paries    48.666667   NaN   NaN   NaN   45.0

# %%
dates=['2017-12-05','Jan 5,2017','01/05/2017','2017.01.05','2017/01/05','20170105','5 jan 2017','6 january2019']

# %%
pd.to_datetime(dates,dayfirst=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[183], line 1
# ----> 1 pd.to_datetime(dates,dayfirst=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1082, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1080         result = _convert_and_box_cache(argc, cache_array)
#    1081     else:
# -> 1082         result = convert_listlike(argc, format)
#    1083 else:
#    1084     result = convert_listlike(np.array([arg]), format)[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# ...

# %%
pd.to_datetime('01/2/15',yearfirst=True)
# Out:
# Timestamp('2001-02-15 00:00:00')

# %%
pd.to_datetime('05/2/2015',dayfirst=True)
# Out:
# Timestamp('2015-02-05 00:00:00')

# %%
datas=pd.read_csv(r'C:\study materials\data science\pandas\stock_data.csv',parse_dates=['Date'],index_col='Date')

# %%
datas
# Out:
#              Open   High    Low  Close    Volume   Name
# Date
# 2006-01-03  39.69  41.22  38.79  40.91  24232729   AABA
# 2006-01-04  41.22  41.90  40.77  40.97  20553479   AABA
# 2006-01-05  40.93  41.73  40.85  41.53  12829610   AABA
# 2006-01-06  42.88  43.57  42.80  43.21  29422828   alex
# 2006-01-09  43.10  43.66  42.82  43.42  16268338  queen
# ...           ...    ...    ...    ...       ...    ...
# 2017-12-22  71.42  71.87  71.22  71.58  10979165   AABA
# 2017-12-26  70.94  71.39  69.63  69.86   8542802   AABA
# 2017-12-27  69.77  70.49  69.69  70.06   6345124   AABA
# 2017-12-28  70.12  70.32  69.51  69.82   7556877   AABA
# 2017-12-29  69.79  70.13  69.43  69.85   6613070   AABA
#
# [3019 rows x 6 columns]

# %%
plot_data=datas.Close.resample('W').mean()

# %%
plot_data
# Out:
# Date
# 2006-01-08    41.6550
# 2006-01-15    41.8120
# 2006-01-22    35.8400
# 2006-01-29    34.7580
# 2006-02-05    34.4440
#                ...
# 2017-12-03    70.9140
# 2017-12-10    69.4640
# 2017-12-17    70.4120
# 2017-12-24    70.8840
# 2017-12-31    69.8975
# Freq: W-SUN, Name: Close, Length: 626, dtype: float64

# %%
drng=pd.date_range(start='08/1/2006',end='1/22/2017',freq='D')

# %%
datas.set_index(drng,inplace=False)
datas['08/01/2006':'1/22/2017'].Close.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10396\881497062.py in ?()
# ----> 1 datas.set_index(drng,inplace=False)
#       2 datas['08/01/2006':'1/22/2017'].Close.mean()
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5906
#    5907             if len(arrays[-1]) != len(self):
#    5908                 # check newest element against length of calling frame, since
#    5909                 # ensure_index_from_sequences would not raise for append=False.
# -> 5910                 raise ValueError(
#    5911                     f"Length mismatch: Expected {len(self)} rows, "
#    5912                     f"received array of length {len(arrays[-1])}"
#    5913                 )
#
# ValueError: Length mismatch: Expected 3019 rows, received array of length 3828

# %%
datas.asfreq("B")
# Out:
#              Open   High    Low  Close      Volume   Name
# Date
# 2006-01-03  39.69  41.22  38.79  40.91  24232729.0   AABA
# 2006-01-04  41.22  41.90  40.77  40.97  20553479.0   AABA
# 2006-01-05  40.93  41.73  40.85  41.53  12829610.0   AABA
# 2006-01-06  42.88  43.57  42.80  43.21  29422828.0   alex
# 2006-01-09  43.10  43.66  42.82  43.42  16268338.0  queen
# ...           ...    ...    ...    ...         ...    ...
# 2017-12-25    NaN    NaN    NaN    NaN         NaN    NaN
# 2017-12-26  70.94  71.39  69.63  69.86   8542802.0   AABA
# 2017-12-27  69.77  70.49  69.69  70.06   6345124.0   AABA
# 2017-12-28  70.12  70.32  69.51  69.82   7556877.0   AABA
# 2017-12-29  69.79  70.13  69.43  69.85   6613070.0   AABA
#
# [3129 rows x 6 columns]

# %%
datas.asfreq("W")
# Out:
#             Open  High  Low  Close  Volume Name
# Date
# 2006-01-08   NaN   NaN  NaN    NaN     NaN  NaN
# 2006-01-15   NaN   NaN  NaN    NaN     NaN  NaN
# 2006-01-22   NaN   NaN  NaN    NaN     NaN  NaN
# 2006-01-29   NaN   NaN  NaN    NaN     NaN  NaN
# 2006-02-05   NaN   NaN  NaN    NaN     NaN  NaN
# ...          ...   ...  ...    ...     ...  ...
# 2017-11-26   NaN   NaN  NaN    NaN     NaN  NaN
# 2017-12-03   NaN   NaN  NaN    NaN     NaN  NaN
# 2017-12-10   NaN   NaN  NaN    NaN     NaN  NaN
# 2017-12-17   NaN   NaN  NaN    NaN     NaN  NaN
# 2017-12-24   NaN   NaN  NaN    NaN     NaN  NaN
#
# [625 rows x 6 columns]

# %%
datas.asfreq("D",method="pad")
# Out:
#              Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03  39.69  41.22  38.79  40.91  24232729  AABA
# 2006-01-04  41.22  41.90  40.77  40.97  20553479  AABA
# 2006-01-05  40.93  41.73  40.85  41.53  12829610  AABA
# 2006-01-06  42.88  43.57  42.80  43.21  29422828  alex
# 2006-01-07  42.88  43.57  42.80  43.21  29422828  alex
# ...           ...    ...    ...    ...       ...   ...
# 2017-12-25  71.42  71.87  71.22  71.58  10979165  AABA
# 2017-12-26  70.94  71.39  69.63  69.86   8542802  AABA
# 2017-12-27  69.77  70.49  69.69  70.06   6345124  AABA
# 2017-12-28  70.12  70.32  69.51  69.82   7556877  AABA
# 2017-12-29  69.79  70.13  69.43  69.85   6613070  AABA
#
# [4379 rows x 6 columns]

# %%
pd.date_range(start='1/1/2017',periods=22,freq='D')
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-14', '2017-01-15', '2017-01-16',
#                '2017-01-17', '2017-01-18', '2017-01-19', '2017-01-20',
#                '2017-01-21', '2017-01-22'],
#               dtype='datetime64[ns]', freq='D')

# %%
test_range=pd.date_range(start='11/1/2019',periods=22,freq='D')

# %%
num_series=pd.Series(np.random.randint(1,100,len(test_range)),index=test_range)

# %%
num_series
# Out:
# 2019-11-01    88
# 2019-11-02    67
# 2019-11-03    11
# 2019-11-04    11
# 2019-11-05    25
# 2019-11-06    69
# 2019-11-07    48
# 2019-11-08     3
# 2019-11-09    24
# 2019-11-10    39
# 2019-11-11    14
# 2019-11-12    61
# 2019-11-13    10
# 2019-11-14     3
# 2019-11-15    76
# 2019-11-16     9
# 2019-11-17    39
# 2019-11-18    23
# 2019-11-19    32
# 2019-11-20    19
# 2019-11-21    80
# 2019-11-22    17
# Freq: D, dtype: int32

# %%
pd.to_datetime('abc')
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[208], line 1
# ----> 1 pd.to_datetime('abc')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1084, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1082         result = convert_listlike(argc, format)
#    1083 else:
# -> 1084     result = convert_listlike(np.array([arg]), format)[0]
#    1085     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1086         result = bool(result)  # TODO: avoid this kludge.
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:455, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     452 if format is not None and format != "mixed":
#     453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# ...

# %%
pd.to_datetime('abc',errors='ignore')
# Out:
# 'abc'

# %%
pd.to_datetime('abc',errors='coerce')
# Out:
# NaT

# %%
pd.to_datetime('01-01-2019',format='%d-%m-%Y')
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
date=pd.to_datetime('01-01-2019',format='%d-%m-%Y')

# %%
date+pd.DateOffset(months=5)
# Out:
# Timestamp('2019-06-01 00:00:00')

# %%
p=pd.Period(2019)

# %%
p1=pd.Period('2017-01')

# %%
p.start_time
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
p.end_time
# Out:
# Timestamp('2019-12-31 23:59:59.999999999')

# %%
p.year
# Out:
# 2019

# %%
p.asfreq('M',how='start')
# Out:
# Period('2019-01', 'M')

# %%
pd.period_range('2017','2019')
# Out:
# PeriodIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#              '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#              '2017-01-09', '2017-01-10',
#              ...
#              '2018-12-23', '2018-12-24', '2018-12-25', '2018-12-26',
#              '2018-12-27', '2018-12-28', '2018-12-29', '2018-12-30',
#              '2018-12-31', '2019-01-01'],
#             dtype='period[D]', length=731)

# %%
pd.period_range('2017','2019',freq='Y')
# Out:
# PeriodIndex(['2017', '2018', '2019'], dtype='period[A-DEC]')

# %%
pd.period_range('2017-05','2017-08',freq='Q')
# Out:
# PeriodIndex(['2017Q2', '2017Q3'], dtype='period[Q-DEC]')

# %%
index=pd.period_range('2017-05','2017-08',freq='M')

# %%
num_series=pd.Series(np.random.randint(1,100,len(index)),index=index)

# %%
num_series
# Out:
# 2017-05    61
# 2017-06    60
# 2017-07    37
# 2017-08    13
# Freq: M, dtype: int32

# %%
index=pd.period_range('2017-05','2017-08',freq='M')

# %%
newIndx=index.to_timestamp()

# %%
newIndx.to_period()
# Out:
# PeriodIndex(['2017-05', '2017-06', '2017-07', '2017-08'], dtype='period[M]')

# %%
datas.head(2)
# Out:
#              Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03  39.69  41.22  38.79  40.91  24232729  AABA
# 2006-01-04  41.22  41.90  40.77  40.97  20553479  AABA

# %%
for i in datas:
    print(i)
# Out:
# Open
# High
# Low
# Close
# Volume
# Name

# %%
for column,values in datas.items():
    print(column)
    print(values)
# Out:
# Open
# Date
# 2006-01-03    39.69
# 2006-01-04    41.22
# 2006-01-05    40.93
# 2006-01-06    42.88
# 2006-01-09    43.10
#               ...
# 2017-12-22    71.42
# 2017-12-26    70.94
# 2017-12-27    69.77
# 2017-12-28    70.12
# 2017-12-29    69.79
# Name: Open, Length: 3019, dtype: float64
# High
# Date
# 2006-01-03    41.22
# 2006-01-04    41.90
# 2006-01-05    41.73
# 2006-01-06    43.57
# 2006-01-09    43.66
#               ...
# 2017-12-22    71.87
# 2017-12-26    71.39
# 2017-12-27    70.49
# 2017-12-28    70.32
# 2017-12-29    70.13
# Name: High, Length: 3019, dtype: float64
# Low
# Date
# 2006-01-03    38.79
# 2006-01-04    40.77
# 2006-01-05    40.85
# 2006-01-06    42.80
# 2006-01-09    42.82
#               ...
# 2017-12-22    71.22
# 2017-12-26    69.63
# 2017-12-27    69.69
# 2017-12-28    69.51
# 2017-12-29    69.43
# Name: Low, Length: 3019, dtype: float64
# Close
# Date
# 2006-01-03    40.91
# 2006-01-04    40.97
# 2006-01-05    41.53
# 2006-01-06    43.21
# ...

# %%
for index,row in data.iterrows():
    print('row',index)
    print(row)
# Out:
# row 1981-01-01 00:00:00
# gender       NaT
# dob          NaT
# occupation   NaT
# work_exp     NaT
# salary       NaT
# own_house    NaT
# children     NaT
# Name: 1981-01-01 00:00:00, dtype: datetime64[ns]
# row 1981-01-02 00:00:00
# gender       NaT
# dob          NaT
# occupation   NaT
# work_exp     NaT
# salary       NaT
# own_house    NaT
# children     NaT
# Name: 1981-01-02 00:00:00, dtype: datetime64[ns]
# row 1981-01-03 00:00:00
# gender       NaT
# dob          NaT
# occupation   NaT
# work_exp     NaT
# salary       NaT
# own_house    NaT
# children     NaT
# Name: 1981-01-03 00:00:00, dtype: datetime64[ns]
# row 1981-01-04 00:00:00
# gender       NaT
# dob          NaT
# occupation   NaT
# work_exp     NaT
# salary       NaT
# own_house    NaT
# children     NaT
# Name: 1981-01-04 00:00:00, dtype: datetime64[ns]
# row 1981-01-05 00:00:00
# gender       NaT
# dob          NaT
# occupation   NaT
# work_exp     NaT
# salary       NaT
# own_house    NaT
# children     NaT
# ...

# %%
def square(x):
    return x*x
abc=[1]
